# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahitha-Banu/Airbnb-Analysis/blob/main/AirbnbAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo

# %%
import pymongo
import pandas as pd

# %%
client =  pymongo.MongoClient("mongodb+srv://aslamsdik9:Arshad7862@cluster0.fmv4j1w.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db= client["sample_airbnb"]
coll= db["listingsAndReviews"]

# %%
data= []

for i in coll.find({},{"_id":1, "listing_url":1, "name":1, 'property_type':1, 'room_type':1, 'bed_type':1,
                       'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1,
                       'bedrooms':1, 'beds':1, 'number_of_reviews':1, 'bathrooms':1, 'price':1,
                       'security_deposit':1, 'extra_people':1, 'guests_included':1, 'images.picture_url':1,
                       'review_scores':1,'cleaning_fee':1}):
    data.append(i)

# %%
df = pd.DataFrame(data)

# %%
df["images"] = df["images"].apply(lambda x: x["picture_url"])
df["review_scores"] = df["review_scores"].apply(lambda x: x.get("review_scores_rating",0))

# %%
df.isna().sum()

# %%
df["bedrooms"].fillna(0, inplace = True)
df["beds"].fillna(0, inplace = True)
df["bathrooms"].fillna(0, inplace = True)
df["security_deposit"].fillna(0, inplace = True)
df["cleaning_fee"].fillna(0, inplace = True)

# %%
df.isna().sum()

# %%
df.dtypes

# %%
df["minimum_nights"] = df["minimum_nights"].astype(int)
df["maximum_nights"] = df["maximum_nights"].astype(int)
df["bedrooms"] = df["bedrooms"].astype(int)
df["beds"] = df["beds"].astype(int)
df["bathrooms"] = df["bathrooms"].astype(str).astype(float).astype(int)
df["price"] = df["price"].astype(str).astype(float).astype(int)
df["security_deposit"] = df["security_deposit"].astype(str).astype(float).astype(int)
df["cleaning_fee"] = df['cleaning_fee'].astype(str).astype(float).astype(int)
df["extra_people"] = df["extra_people"].astype(str).astype(float).astype(int)
df["guests_included"] = df["guests_included"].astype(str).astype(float).astype(int)

# %%
df.dtypes

# %%
df.head(2)

# %%
#Collecting the HOST details
hostData = []
for i in coll.find({},{"_id":1, "host":1}):
  hostData.append(i)

# %%
dfHost = pd.DataFrame(hostData)

# %%
hostColumns= {'_id':[],'host_id':[], 'host_url':[], 'host_name':[], 'host_location':[],"host_response_time":[],
               'host_thumbnail_url':[], 'host_picture_url':[], 'host_neighbourhood':[], 'host_response_rate':[],
               'host_is_superhost':[], 'host_has_profile_pic':[], 'host_identity_verified':[], 'host_listings_count':[],
               'host_total_listings_count':[], 'host_verifications':[]}

for i in dfHost["_id"]:
    hostColumns["_id"].append(i)
for i in dfHost["host"]:
    hostColumns["host_id"].append(i["host_id"])
    hostColumns["host_url"].append(i["host_url"])
    hostColumns["host_name"].append(i["host_name"])
    hostColumns["host_location"].append(i["host_location"])
    hostColumns["host_response_time"].append(i.get("host_response_time"))
    hostColumns["host_thumbnail_url"].append(i["host_thumbnail_url"])
    hostColumns["host_picture_url"].append(i["host_picture_url"])
    hostColumns["host_neighbourhood"].append(i["host_neighbourhood"])
    hostColumns["host_response_rate"].append(i.get("host_response_rate"))
    hostColumns["host_is_superhost"].append(i["host_is_superhost"])
    hostColumns["host_has_profile_pic"].append(i["host_has_profile_pic"])
    hostColumns["host_identity_verified"].append(i["host_identity_verified"])
    hostColumns["host_listings_count"].append(i["host_listings_count"])
    hostColumns["host_total_listings_count"].append(i["host_total_listings_count"])
    hostColumns["host_verifications"].append(i["host_verifications"])
dfHostUpdate = pd.DataFrame(hostColumns)

# %%
dfHostUpdate.head(2)
# Out:
#         _id   host_id                                    host_url host_name  \
# 0  10051164  51326285  https://www.airbnb.com/users/show/51326285   Beatriz
# 1  10092679  21331922  https://www.airbnb.com/users/show/21331922       Ali
#
#                                      host_location host_response_time  \
# 0  Rio de Janeiro, State of Rio de Janeiro, Brazil     within an hour
# 1                                         İstanbul     within an hour
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1  https://a0.muscache.com/im/pictures/user/bcd9b...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
# 1  https://a0.muscache.com/im/pictures/user/bcd9b...             Taksim
#
#    host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                80.0              False                  True
# ...

# %%
dfHostUpdate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _id                        5555 non-null   object
#  1   host_id                    5555 non-null   object
#  2   host_url                   5555 non-null   object
#  3   host_name                  5555 non-null   object
#  4   host_location              5555 non-null   object
#  5   host_response_time         4167 non-null   object
#  6   host_thumbnail_url         5555 non-null   object
#  7   host_picture_url           5555 non-null   object
#  8   host_neighbourhood         5555 non-null   object
#  9   host_response_rate         4167 non-null   float64
#  10  host_is_superhost          5555 non-null   bool
#  11  host_has_profile_pic       5555 non-null   bool
#  12  host_identity_verified     5555 non-null   bool
# ...

# %%
dfHostUpdate.isna().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
# host_neighbourhood have more empty values ('')
# Finding the how many values are empty
list_index= []
for index,row in dfHostUpdate.iterrows():
    if row["host_neighbourhood"] =='':
        list_index.append(index)

# %%
len(list_index)
# Out:
# 1923

# %%
# "host_neighbourhood" have a "1923" empty values ('')
# so we want to replace thet empty values
dfHostUpdate["host_response_time"].fillna("Not Specified",inplace= True)
dfHostUpdate["host_response_rate"].fillna("Not Specified",inplace= True)
dfHostUpdate["host_neighbourhood"] = dfHostUpdate["host_neighbourhood"].replace({'':"Not Specified"})

# %%
dfHostUpdate.isna().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
dfHostUpdate.head(2)
# Out:
#         _id   host_id                                    host_url host_name  \
# 0  10051164  51326285  https://www.airbnb.com/users/show/51326285   Beatriz
# 1  10092679  21331922  https://www.airbnb.com/users/show/21331922       Ali
#
#                                      host_location host_response_time  \
# 0  Rio de Janeiro, State of Rio de Janeiro, Brazil     within an hour
# 1                                         İstanbul     within an hour
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1  https://a0.muscache.com/im/pictures/user/bcd9b...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
# 1  https://a0.muscache.com/im/pictures/user/bcd9b...             Taksim
#
#   host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0               80.0              False                  True
# ...

# %%
# Changing the "True" or "False" features

dfHostUpdate["host_is_superhost"] = dfHostUpdate["host_is_superhost"].map({False: "No", True: "Yes"})
dfHostUpdate["host_has_profile_pic"] = dfHostUpdate["host_has_profile_pic"].map({False: "No", True: "Yes"})
dfHostUpdate["host_identity_verified"] = dfHostUpdate["host_identity_verified"].map({False: "No", True: "Yes"})

# %%
#Collecting the Address
address = []
for i in coll.find({},{"_id":1, "address":1}):
  address.append(i)

# %%
dfAddress = pd.DataFrame(address)

# %%
addressColumn = {"_id": [], "street": [], "suburb": [], 'government_area': [], "market": [],
                 "country": [], "country_code": [], "location_type": [],
                 "longitude": [], "latitude": [], 'is_location_exact': []}
for i in dfAddress["_id"]:
  addressColumn["_id"].append(i)

for j in dfAddress["address"]:
  addressColumn["street"].append(j["street"])
  addressColumn['suburb'].append(j['suburb'])
  addressColumn["government_area"].append(j["government_area"])
  addressColumn["market"].append(j["market"])
  addressColumn["country"].append(j["country"])
  addressColumn["country_code"].append(j["country_code"])
  addressColumn["location_type"].append(j["location"]["type"])
  addressColumn["longitude"].append(j["location"]["coordinates"][0])
  addressColumn["latitude"].append(j["location"]["coordinates"][1])
  addressColumn["is_location_exact"].append(j["location"]["is_location_exact"])

# %%
dfAddressUpdate = pd.DataFrame(addressColumn)

# %%
dfAddressUpdate.head(2)
# Out:
#         _id                                  street   suburb government_area  \
# 0  10051164  Rio de Janeiro, Rio de Janeiro, Brazil   Catete          Catete
# 1  10092679               Beyoğlu, İstanbul, Turkey  Beyoglu         Beyoglu
#
#            market country country_code location_type  longitude   latitude  \
# 0  Rio De Janeiro  Brazil           BR         Point -43.180157 -22.926382
# 1        Istanbul  Turkey           TR         Point  28.958250  41.037770
#
#    is_location_exact
# 0               True
# 1              False

# %%
dfAddressUpdate.isna().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
dfAddressUpdate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                5555 non-null   object
#  1   street             5555 non-null   object
#  2   suburb             5555 non-null   object
#  3   government_area    5555 non-null   object
#  4   market             5555 non-null   object
#  5   country            5555 non-null   object
#  6   country_code       5555 non-null   object
#  7   location_type      5555 non-null   object
#  8   longitude          5555 non-null   float64
#  9   latitude           5555 non-null   float64
#  10  is_location_exact  5555 non-null   bool
# dtypes: bool(1), float64(2), object(8)
# memory usage: 439.5+ KB

# %%
# Checking the empty values ('') for all features
id_e=[]
stre_e=[]
suburb_e=[]
gov_e=[]
mark_e=[]
cntry_e=[]
cntry_co_e=[]
loc_ty_e=[]
long_e=[]
lat_e=[]
is_loc_tr_e=[]
for index,row in dfAddressUpdate.iterrows():
    if row["_id"] == '':
        id_e.append(index)

    if row["street"] == '':
        stre_e.append(index)

    if row["suburb"] == '':
        suburb_e.append(index)

    if row["government_area"] == '':
        gov_e.append(index)

    if row["market"] == '':
        mark_e.append(index)

    if row["country"] == '':
        cntry_e.append(index)

    if row["country_code"] == '':
        cntry_co_e.append(index)

    if row["location_type"] == '':
        loc_ty_e.append(index)

    if row["longitude"] == '':
        long_e.append(index)

    if row["latitude"] == '':
        lat_e.append(index)

    if row["is_location_exact"] == '':
        is_loc_tr_e.append(index)

empty_columns=[id_e,stre_e,suburb_e,gov_e,mark_e,cntry_e,cntry_co_e,loc_ty_e,long_e,lat_e,is_loc_tr_e]
for i in empty_columns:
    print(len(i))
# Out:
# 0
# 0
# 887
# 0
# 6
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# Handling the empty values

dfAddressUpdate["suburb"] = dfAddressUpdate["suburb"].replace({'':"Not Specified"})
dfAddressUpdate["market"] = dfAddressUpdate["market"].replace({'':"Not Specified"})
dfAddressUpdate["is_location_exact"] = dfAddressUpdate["is_location_exact"].map({False:"No", True:"Yes"})

# %%
#Collecting the availability
available = []

for i in coll.find({}, {"_id": 1, "availability": 1}):
  available.append(i)

dfAvailable = pd.DataFrame(available)

# %%
availableColumn = {"_id": [], 'availability_30': [], 'availability_60': [], 'availability_90': [], 'availability_365': []}

for i in dfAvailable["_id"]:
  availableColumn["_id"].append(i)

for j in dfAvailable["availability"]:
  availableColumn["availability_30"].append(j['availability_30'])
  availableColumn["availability_60"].append(j['availability_60'])
  availableColumn["availability_90"].append(j['availability_90'])
  availableColumn["availability_365"].append(j['availability_365'])

dfAvailableUpdate = pd.DataFrame(availableColumn)

# %%
dfAvailableUpdate.isna().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
dfAvailableUpdate.head(2)
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0  10051164               10               10               21
# 1  10092679                3               19               37
#
#    availability_365
# 0               296
# 1                37

# %%
dfAvailableUpdate.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %%
#Collecting the Amenities

amenities = []

for i in coll.find({},{"_id":1, 'amenities': 1}):
  amenities.append(i)

dfAmenities = pd.DataFrame(amenities)

# %%
def sortAmenities(x):
  a = x
  a.sort()
  return a

dfAmenities["amenities"]= dfAmenities["amenities"].apply(lambda x: sortAmenities(x))

# %%
dfAmenities.isna().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
#Merging all the dataframes
#df
#dfHostUpdate
#dfAddressUpdate
#dfAvailableUpdate
#dfAmenities

dfAirbnb = pd.merge(df, dfHostUpdate, on = "_id")
dfAirbnb = pd.merge(dfAirbnb, dfAddressUpdate, on = "_id")
dfAirbnb = pd.merge(dfAirbnb, dfAvailableUpdate, on = "_id")
dfAirbnb = pd.merge(dfAirbnb, dfAmenities, on = "_id")

# %%
dfAirbnb

# %%
# download as csv
dfAirbnb.to_csv('airbnb.csv', index=False)
